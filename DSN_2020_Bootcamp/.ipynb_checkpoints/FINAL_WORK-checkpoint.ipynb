# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_columns = 80
pd.options.display.max_rows = 81

# %%
data = pd.read_csv('Train.csv')
data2 = pd.read_csv('Test.csv')

# %%
new_data = pd.concat([data,data2]).reset_index(drop=True)
new_data.shape
# Out:
# (80000, 52)

# %%
new_data.drop(['Applicant_ID'], axis =1, inplace = True)
data.drop(['Applicant_ID'], axis =1, inplace = True)
data2.drop(['Applicant_ID'], axis =1, inplace = True)

# %%
#new_data.drop(['form_field5', 'form_field10', 'form_field17', 
               #'form_field18', 'form_field20', 'form_field22', 
               #'form_field23', 'form_field26', 'form_field27', 
               #'form_field28', 'form_field29', 'form_field32', 
               #'form_field37', 'form_field39', 'form_field46', 'form_field49'], axis =1, inplace = True)
                
## Drop rows with much missing values > 70%
new_data.drop(["form_field40"], axis =1, inplace = True)
new_data.drop(["form_field31"], axis =1, inplace = True)
#new_data.drop(["form_field40","form_field41", 'form_field31','form_field45',"form_field11"], axis =1, inplace = True)

# %%
#pd.crosstab(new_data.form_field44, new_data.default_status)
#pd.crosstab(new_data.form_field5, new_data.default_status)

# %%
new_data['forma'] = new_data['form_field6'] + new_data['form_field7']+ new_data['form_field8']+ new_data['form_field9']+new_data['form_field12']
    
#new_data.drop(["form_field6","form_field7", 'form_field8','form_field12'], axis =1, inplace = True)

# %%
new_data['formb'] = new_data['form_field21'] + new_data['form_field24']+ new_data['form_field25']
#new_data.drop(["form_field21","form_field24", 'form_field25'], axis =1, inplace = True)

# %%
new_data['formc'] = new_data['form_field48'] + new_data['form_field50']
new_data.drop(["form_field48", 'form_field50'], axis =1, inplace = True)


new_data['formd'] = new_data['forma'] + new_data['formb'] + new_data['formc']

# %%
list1 = ['form_field2','form_field3','form_field4', 'form_field9',
        'form_field13','form_field16','form_field19','form_field34','form_field35',
        'form_field36','form_field38','form_field42']
for col in list1:
    #new_data[col].fillna(method = 'ffill', inplace = True)
    new_data[col].fillna(0, inplace = True)

# %%
list2 = ['forma','formb','formc','formd','form_field15','form_field33','form_field44']
for col in list2:
    #new_data[col].fillna(method = 'ffill', inplace = True)
    new_data[col].fillna(new_data[col].median(), inplace = True)

# %%
mcolumns = new_data.columns[new_data.isna().any()]
mcolumns = mcolumns[:-1]


for column in mcolumns:
    #new_data[col].fillna(method = 'ffill', inplace = True)
    new_data[column].fillna(-999, inplace = True)

# %%
new_data.columns
# Out:
# Index(['form_field1', 'form_field2', 'form_field3', 'form_field4',
#        'form_field5', 'form_field6', 'form_field7', 'form_field8',
#        'form_field9', 'form_field10', 'form_field11', 'form_field12',
#        'form_field13', 'form_field14', 'form_field15', 'form_field16',
#        'form_field17', 'form_field18', 'form_field19', 'form_field20',
#        'form_field21', 'form_field22', 'form_field23', 'form_field24',
#        'form_field25', 'form_field26', 'form_field27', 'form_field28',
#        'form_field29', 'form_field30', 'form_field32', 'form_field33',
#        'form_field34', 'form_field35', 'form_field36', 'form_field37',
#        'form_field38', 'form_field39', 'form_field41', 'form_field42',
#        'form_field43', 'form_field44', 'form_field45', 'form_field46',
#        'form_field47', 'form_field49', 'default_status', 'forma', 'formb',
#        'formc', 'formd'],
#       dtype='object')

# %%
for col in new_data.drop(['form_field47','default_status'], axis =1).columns:
    
    new_data[col].plot(kind='hist', title = 'Hist' + col)
    plt.show()

# %%
new_data.form_field47[new_data.form_field47 == 'charge'] = 1
new_data.form_field47[new_data.form_field47 == 'lending'] = 0
new_data.form_field47 = new_data.form_field47.astype(int)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn import preprocessing
sc = StandardScaler()
ms = MinMaxScaler()

# %%
from sklearn.model_selection import train_test_split
train = new_data[0:56000]
test = new_data[56000:]
train.default_status[train.default_status == 'no'] = 0
train.default_status[train.default_status == 'yes'] = 1
train['default_status'] = train['default_status'].astype(int)

# %%
X = train.drop(['default_status'], axis = 1)
y = train['default_status']
#X= preprocessing.scale(X)
#from sklearn.feature_selection import SelectKBest
#from sklearn.feature_selection import chi2
#X = SelectKBest(chi2, k=18).fit_transform(X,y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=19)

# %%
#test.drop(['default_status'], axis =1 , inplace = True)

# %%
#!pip install catboost

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, precision_score, classification_report
from sklearn.metrics import roc_auc_score
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression

# %%
## using stratified KFold

# %%
from sklearn.model_selection import StratifiedKFold

# %%
seed = 2020
parameters = {
              'n_estimators': 4000,
              'learning_rate': 0.009,
              'loss_function': 'CrossEntropy',
              'max_depth': 8,
              #'task_type':'GPU',
              'eval_metric':'AUC',
              'random_seed': seed,
              'early_stopping_rounds': 300,
              'use_best_model': True,
}

# %%
fold_score = 0
test_pred = []

n = 8
kf = StratifiedKFold(n)

for train_index, test_index in kf.split(X, y):
    Xtrain, Xtest = X.loc[train_index], X.loc[test_index]
    ytrain, ytest = y[train_index], y[test_index]

    cat_model = CatBoostClassifier(**parameters)
    cat_model.fit(Xtrain, ytrain, eval_set=[(Xtest,ytest)], verbose=200)
    
    pred = cat_model.predict_proba(Xtest)[:, 1]
    score = roc_auc_score(ytest, pred)
    fold_score = fold_score + (score/n)
    print(fold_score)
    
    predictions = cat_model.predict_proba(test)[:, 1]
    test_pred.append(predictions)
# Out:
# 0:	test: 0.7997610	best: 0.7997610 (0)	total: 67.6ms	remaining: 4m 30s
# 200:	test: 0.8246760	best: 0.8246760 (199)	total: 11.5s	remaining: 3m 37s
# 400:	test: 0.8275284	best: 0.8275284 (400)	total: 22.9s	remaining: 3m 25s
# 600:	test: 0.8295361	best: 0.8295361 (600)	total: 34.2s	remaining: 3m 13s
# 800:	test: 0.8310501	best: 0.8310501 (800)	total: 45.4s	remaining: 3m 1s
# 1000:	test: 0.8320951	best: 0.8320965 (998)	total: 56.5s	remaining: 2m 49s
# 1200:	test: 0.8330842	best: 0.8330842 (1200)	total: 1m 7s	remaining: 2m 37s
# 1400:	test: 0.8338889	best: 0.8338898 (1399)	total: 1m 18s	remaining: 2m 26s
# 1600:	test: 0.8345867	best: 0.8345867 (1600)	total: 1m 29s	remaining: 2m 14s
# 1800:	test: 0.8350959	best: 0.8350959 (1800)	total: 1m 41s	remaining: 2m 3s
# 2000:	test: 0.8355302	best: 0.8355318 (1999)	total: 1m 52s	remaining: 1m 52s
# 2200:	test: 0.8360793	best: 0.8360793 (2200)	total: 2m 3s	remaining: 1m 40s
# 2400:	test: 0.8364646	best: 0.8364646 (2400)	total: 2m 14s	remaining: 1m 29s
# 2600:	test: 0.8368478	best: 0.8368478 (2600)	total: 2m 25s	remaining: 1m 18s
# 2800:	test: 0.8372566	best: 0.8372719 (2791)	total: 2m 37s	remaining: 1m 7s
# 3000:	test: 0.8376099	best: 0.8376099 (3000)	total: 2m 48s	remaining: 56s
# 3200:	test: 0.8379113	best: 0.8379113 (3200)	total: 2m 59s	remaining: 44.7s
# 3400:	test: 0.8381062	best: 0.8381082 (3399)	total: 3m 10s	remaining: 33.5s
# 3600:	test: 0.8382256	best: 0.8382392 (3561)	total: 3m 21s	remaining: 22.3s
# 3800:	test: 0.8383788	best: 0.8383840 (3797)	total: 3m 32s	remaining: 11.1s
# 3999:	test: 0.8384258	best: 0.8384384 (3967)	total: 3m 43s	remaining: 0us
#
# bestTest = 0.838438406
# bestIteration = 3967
#
# Shrink model to first 3968 iterations.
# 0.10480480075283072
# 0:	test: 0.8105435	best: 0.8105435 (0)	total: 62ms	remaining: 4m 7s
# 200:	test: 0.8306649	best: 0.8306649 (200)	total: 11.8s	remaining: 3m 43s
# 400:	test: 0.8347635	best: 0.8347635 (400)	total: 23.8s	remaining: 3m 34s
# 600:	test: 0.8372702	best: 0.8372702 (600)	total: 35.6s	remaining: 3m 21s
# 800:	test: 0.8388717	best: 0.8388717 (800)	total: 47.1s	remaining: 3m 8s
# 1000:	test: 0.8400643	best: 0.8400643 (1000)	total: 58.6s	remaining: 2m 55s
# 1200:	test: 0.8409442	best: 0.8409442 (1200)	total: 1m 10s	remaining: 2m 43s
# 1400:	test: 0.8416273	best: 0.8416273 (1400)	total: 1m 21s	remaining: 2m 31s
# 1600:	test: 0.8421473	best: 0.8421515 (1598)	total: 1m 32s	remaining: 2m 19s
# 1800:	test: 0.8426035	best: 0.8426035 (1800)	total: 1m 44s	remaining: 2m 7s
# 2000:	test: 0.8428680	best: 0.8428689 (1996)	total: 1m 55s	remaining: 1m 55s
# 2200:	test: 0.8431943	best: 0.8431943 (2200)	total: 2m 7s	remaining: 1m 43s
# 2400:	test: 0.8434121	best: 0.8434220 (2396)	total: 2m 18s	remaining: 1m 32s
# 2600:	test: 0.8435649	best: 0.8435649 (2600)	total: 2m 29s	remaining: 1m 20s
# 2800:	test: 0.8437450	best: 0.8437450 (2800)	total: 2m 41s	remaining: 1m 9s
# 3000:	test: 0.8439052	best: 0.8439052 (3000)	total: 2m 52s	remaining: 57.5s
# 3200:	test: 0.8440643	best: 0.8440752 (3197)	total: 3m 4s	remaining: 45.9s
# 3400:	test: 0.8441384	best: 0.8441521 (3350)	total: 3m 15s	remaining: 34.4s
# 3600:	test: 0.8441730	best: 0.8441757 (3596)	total: 3m 27s	remaining: 22.9s
# 3800:	test: 0.8441644	best: 0.8441766 (3792)	total: 3m 38s	remaining: 11.4s
# 3999:	test: 0.8441944	best: 0.8442071 (3989)	total: 3m 50s	remaining: 0us
#
# bestTest = 0.8442070951
# bestIteration = 3989
#
# Shrink model to first 3990 iterations.
# 0.2103306876423533
# 0:	test: 0.8031013	best: 0.8031013 (0)	total: 60.3ms	remaining: 4m 1s
# 200:	test: 0.8236547	best: 0.8236734 (199)	total: 12s	remaining: 3m 46s
# 400:	test: 0.8278411	best: 0.8278411 (400)	total: 23.7s	remaining: 3m 32s
# 600:	test: 0.8306598	best: 0.8306598 (600)	total: 35.3s	remaining: 3m 19s
# 800:	test: 0.8324017	best: 0.8324017 (800)	total: 47s	remaining: 3m 7s
# 1000:	test: 0.8336798	best: 0.8336798 (1000)	total: 58.5s	remaining: 2m 55s
# 1200:	test: 0.8346635	best: 0.8346635 (1200)	total: 1m 9s	remaining: 2m 43s
# 1400:	test: 0.8353685	best: 0.8353685 (1400)	total: 1m 21s	remaining: 2m 31s
# 1600:	test: 0.8359092	best: 0.8359092 (1600)	total: 1m 33s	remaining: 2m 19s
# 1800:	test: 0.8363931	best: 0.8363932 (1799)	total: 1m 45s	remaining: 2m 8s
# 2000:	test: 0.8367986	best: 0.8367986 (2000)	total: 1m 56s	remaining: 1m 56s
# 2200:	test: 0.8370957	best: 0.8371103 (2184)	total: 2m 8s	remaining: 1m 44s
# 2400:	test: 0.8372911	best: 0.8372932 (2392)	total: 2m 19s	remaining: 1m 32s
# 2600:	test: 0.8375761	best: 0.8375761 (2600)	total: 2m 31s	remaining: 1m 21s
# 2800:	test: 0.8378211	best: 0.8378214 (2799)	total: 2m 42s	remaining: 1m 9s
# 3000:	test: 0.8380353	best: 0.8380406 (2999)	total: 2m 54s	remaining: 58.1s
# 3200:	test: 0.8382345	best: 0.8382345 (3200)	total: 3m 6s	remaining: 46.4s
# 3400:	test: 0.8383964	best: 0.8383991 (3399)	total: 3m 17s	remaining: 34.8s
# 3600:	test: 0.8385690	best: 0.8385767 (3570)	total: 3m 29s	remaining: 23.2s
# 3800:	test: 0.8386941	best: 0.8386945 (3746)	total: 3m 40s	remaining: 11.6s
# 3999:	test: 0.8387598	best: 0.8387664 (3937)	total: 3m 52s	remaining: 0us
#
# bestTest = 0.838766434
# bestIteration = 3937
#
# Shrink model to first 3938 iterations.
# 0.31517649188693764
# 0:	test: 0.8066727	best: 0.8066727 (0)	total: 68.8ms	remaining: 4m 35s
# 200:	test: 0.8243612	best: 0.8243695 (199)	total: 12.2s	remaining: 3m 50s
# 400:	test: 0.8284142	best: 0.8284142 (400)	total: 24.1s	remaining: 3m 36s
# 600:	test: 0.8309783	best: 0.8309783 (600)	total: 35.8s	remaining: 3m 22s
# 800:	test: 0.8327248	best: 0.8327248 (800)	total: 47.3s	remaining: 3m 8s
# 1000:	test: 0.8339425	best: 0.8339531 (999)	total: 58.9s	remaining: 2m 56s
# 1200:	test: 0.8350489	best: 0.8350489 (1200)	total: 1m 10s	remaining: 2m 44s
# 1400:	test: 0.8359643	best: 0.8359643 (1400)	total: 1m 22s	remaining: 2m 33s
# 1600:	test: 0.8366746	best: 0.8366746 (1600)	total: 1m 34s	remaining: 2m 22s
# 1800:	test: 0.8372913	best: 0.8372913 (1800)	total: 1m 47s	remaining: 2m 11s
# 2000:	test: 0.8377867	best: 0.8377943 (1996)	total: 1m 59s	remaining: 1m 59s
# 2200:	test: 0.8381933	best: 0.8381933 (2200)	total: 2m 11s	remaining: 1m 47s
# 2400:	test: 0.8384845	best: 0.8384865 (2399)	total: 2m 23s	remaining: 1m 35s
# 2600:	test: 0.8388162	best: 0.8388169 (2597)	total: 2m 35s	remaining: 1m 23s
# 2800:	test: 0.8391148	best: 0.8391148 (2800)	total: 2m 47s	remaining: 1m 11s
# 3000:	test: 0.8393720	best: 0.8393720 (3000)	total: 2m 59s	remaining: 59.6s
# 3200:	test: 0.8394932	best: 0.8394945 (3199)	total: 3m 11s	remaining: 47.7s
# 3400:	test: 0.8396334	best: 0.8396334 (3400)	total: 3m 22s	remaining: 35.7s
# 3600:	test: 0.8397014	best: 0.8397066 (3596)	total: 3m 34s	remaining: 23.8s
# 3800:	test: 0.8397374	best: 0.8397846 (3744)	total: 3m 46s	remaining: 11.9s
# 3999:	test: 0.8397955	best: 0.8397978 (3990)	total: 3m 58s	remaining: 0us
#
# bestTest = 0.8397977573
# bestIteration = 3990
#
# Shrink model to first 3991 iterations.
# 0.4201512115510865
# 0:	test: 0.8007364	best: 0.8007364 (0)	total: 62.3ms	remaining: 4m 8s
# 200:	test: 0.8264294	best: 0.8264444 (198)	total: 12.3s	remaining: 3m 53s
# 400:	test: 0.8296708	best: 0.8296708 (400)	total: 24.3s	remaining: 3m 38s
# 600:	test: 0.8317328	best: 0.8317368 (599)	total: 36.1s	remaining: 3m 23s
# 800:	test: 0.8331807	best: 0.8331807 (800)	total: 47.9s	remaining: 3m 11s
# 1000:	test: 0.8342821	best: 0.8342821 (1000)	total: 59.6s	remaining: 2m 58s
# 1200:	test: 0.8352238	best: 0.8352238 (1200)	total: 1m 11s	remaining: 2m 46s
# 1400:	test: 0.8360062	best: 0.8360062 (1400)	total: 1m 23s	remaining: 2m 34s
# 1600:	test: 0.8365721	best: 0.8365721 (1600)	total: 1m 34s	remaining: 2m 22s
# 1800:	test: 0.8369865	best: 0.8369877 (1787)	total: 1m 46s	remaining: 2m 10s
# 2000:	test: 0.8373977	best: 0.8373977 (2000)	total: 1m 58s	remaining: 1m 58s
# 2200:	test: 0.8376899	best: 0.8376899 (2200)	total: 2m 10s	remaining: 1m 46s
# 2400:	test: 0.8378939	best: 0.8378997 (2397)	total: 2m 21s	remaining: 1m 34s
# 2600:	test: 0.8381816	best: 0.8381825 (2596)	total: 2m 33s	remaining: 1m 22s
# 2800:	test: 0.8384326	best: 0.8384326 (2800)	total: 2m 45s	remaining: 1m 10s
# 3000:	test: 0.8387202	best: 0.8387202 (3000)	total: 2m 56s	remaining: 58.9s
# 3200:	test: 0.8389543	best: 0.8389589 (3194)	total: 3m 8s	remaining: 47.1s
# 3400:	test: 0.8390820	best: 0.8390824 (3399)	total: 3m 20s	remaining: 35.3s
# 3800:	test: 0.8390728	best: 0.8391186 (3539)	total: 3m 43s	remaining: 11.7s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8391186335
# bestIteration = 3539
#
# Shrink model to first 3540 iterations.
# 0.5250410407425705
# 0:	test: 0.7924483	best: 0.7924483 (0)	total: 61.5ms	remaining: 4m 6s
# 200:	test: 0.8165678	best: 0.8165720 (199)	total: 12.4s	remaining: 3m 54s
# 400:	test: 0.8208435	best: 0.8208435 (400)	total: 24.7s	remaining: 3m 42s
# 600:	test: 0.8234343	best: 0.8234343 (600)	total: 36.7s	remaining: 3m 27s
# 800:	test: 0.8253196	best: 0.8253196 (800)	total: 48.5s	remaining: 3m 13s
# 1000:	test: 0.8268228	best: 0.8268228 (1000)	total: 1m	remaining: 3m
# 1200:	test: 0.8279840	best: 0.8279858 (1199)	total: 1m 11s	remaining: 2m 47s
# 1400:	test: 0.8288484	best: 0.8288484 (1400)	total: 1m 23s	remaining: 2m 34s
# 1600:	test: 0.8295263	best: 0.8295345 (1598)	total: 1m 34s	remaining: 2m 22s
# 1800:	test: 0.8301695	best: 0.8301695 (1800)	total: 1m 46s	remaining: 2m 10s
# 2000:	test: 0.8305949	best: 0.8305971 (1999)	total: 1m 58s	remaining: 1m 58s
# 2200:	test: 0.8310197	best: 0.8310208 (2197)	total: 2m 9s	remaining: 1m 45s
# 2400:	test: 0.8313473	best: 0.8313473 (2400)	total: 2m 21s	remaining: 1m 33s
# 2600:	test: 0.8316658	best: 0.8316658 (2600)	total: 2m 32s	remaining: 1m 21s
# 2800:	test: 0.8319577	best: 0.8319601 (2793)	total: 2m 43s	remaining: 1m 10s
# 3000:	test: 0.8321968	best: 0.8321968 (3000)	total: 2m 55s	remaining: 58.3s
# 3200:	test: 0.8323265	best: 0.8323347 (3161)	total: 3m 6s	remaining: 46.6s
# 3400:	test: 0.8325314	best: 0.8325314 (3400)	total: 3m 18s	remaining: 34.9s
# 3600:	test: 0.8325383	best: 0.8325573 (3571)	total: 3m 29s	remaining: 23.2s
# 3800:	test: 0.8324887	best: 0.8325573 (3571)	total: 3m 40s	remaining: 11.6s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8325572954
# bestIteration = 3571
#
# Shrink model to first 3572 iterations.
# 0.6291107026659964
# 0:	test: 0.8179734	best: 0.8179734 (0)	total: 63.2ms	remaining: 4m 12s
# 200:	test: 0.8408669	best: 0.8408694 (199)	total: 12.1s	remaining: 3m 48s
# 400:	test: 0.8437438	best: 0.8437438 (400)	total: 24.1s	remaining: 3m 36s
# 600:	test: 0.8453544	best: 0.8453544 (600)	total: 35.9s	remaining: 3m 23s
# 800:	test: 0.8465699	best: 0.8465699 (800)	total: 47.4s	remaining: 3m 9s
# 1000:	test: 0.8473205	best: 0.8473209 (999)	total: 58.9s	remaining: 2m 56s
# 1200:	test: 0.8480397	best: 0.8480439 (1199)	total: 1m 10s	remaining: 2m 44s
# 1400:	test: 0.8485725	best: 0.8485725 (1400)	total: 1m 21s	remaining: 2m 31s
# 1600:	test: 0.8490941	best: 0.8490941 (1600)	total: 1m 33s	remaining: 2m 19s
# 1800:	test: 0.8494229	best: 0.8494238 (1799)	total: 1m 44s	remaining: 2m 8s
# 2000:	test: 0.8497811	best: 0.8497878 (1993)	total: 1m 56s	remaining: 1m 56s
# 2200:	test: 0.8500520	best: 0.8500587 (2199)	total: 2m 8s	remaining: 1m 44s
# 2400:	test: 0.8502133	best: 0.8502133 (2400)	total: 2m 19s	remaining: 1m 33s
# 2600:	test: 0.8504636	best: 0.8504813 (2590)	total: 2m 31s	remaining: 1m 21s
# 2800:	test: 0.8506655	best: 0.8506655 (2800)	total: 2m 42s	remaining: 1m 9s
# 3000:	test: 0.8507058	best: 0.8507295 (2980)	total: 2m 53s	remaining: 57.9s
# 3200:	test: 0.8507756	best: 0.8507776 (3196)	total: 3m 5s	remaining: 46.2s
# 3400:	test: 0.8507408	best: 0.8507826 (3359)	total: 3m 16s	remaining: 34.7s
# 3600:	test: 0.8507391	best: 0.8507826 (3359)	total: 3m 28s	remaining: 23.1s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8507825933
# bestIteration = 3359
#
# Shrink model to first 3360 iterations.
# 0.7354585268341824
# 0:	test: 0.8045020	best: 0.8045020 (0)	total: 71.3ms	remaining: 4m 45s
# 200:	test: 0.8258585	best: 0.8258942 (198)	total: 12.7s	remaining: 4m
# 400:	test: 0.8311279	best: 0.8311279 (400)	total: 25.1s	remaining: 3m 45s
# 600:	test: 0.8339829	best: 0.8339829 (600)	total: 37.5s	remaining: 3m 31s
# 800:	test: 0.8357538	best: 0.8357560 (799)	total: 49.8s	remaining: 3m 18s
# 1000:	test: 0.8371968	best: 0.8371968 (1000)	total: 1m 1s	remaining: 3m 5s
# 1200:	test: 0.8382822	best: 0.8382822 (1200)	total: 1m 13s	remaining: 2m 51s
# 1400:	test: 0.8392324	best: 0.8392324 (1400)	total: 1m 25s	remaining: 2m 37s
# 1600:	test: 0.8399447	best: 0.8399447 (1600)	total: 1m 36s	remaining: 2m 24s
# 1800:	test: 0.8406001	best: 0.8406025 (1799)	total: 1m 48s	remaining: 2m 12s
# 2000:	test: 0.8410629	best: 0.8410629 (2000)	total: 2m	remaining: 2m
# 2200:	test: 0.8414723	best: 0.8414723 (2200)	total: 2m 11s	remaining: 1m 47s
# 2400:	test: 0.8418781	best: 0.8418781 (2400)	total: 2m 23s	remaining: 1m 35s
# 2600:	test: 0.8422934	best: 0.8423015 (2599)	total: 2m 35s	remaining: 1m 23s
# 2800:	test: 0.8426803	best: 0.8426803 (2795)	total: 2m 46s	remaining: 1m 11s
# 3000:	test: 0.8429854	best: 0.8429854 (3000)	total: 2m 58s	remaining: 59.4s
# 3200:	test: 0.8432235	best: 0.8432235 (3198)	total: 3m 9s	remaining: 47.4s
# 3400:	test: 0.8434941	best: 0.8434999 (3397)	total: 3m 21s	remaining: 35.5s
# 3600:	test: 0.8436690	best: 0.8436788 (3593)	total: 3m 33s	remaining: 23.6s
# 3800:	test: 0.8437932	best: 0.8438103 (3767)	total: 3m 45s	remaining: 11.8s
# 3999:	test: 0.8438731	best: 0.8438916 (3976)	total: 3m 56s	remaining: 0us
#
# bestTest = 0.8438916456
# bestIteration = 3976
#
# Shrink model to first 3977 iterations.
# 0.840944982532829

# %%
prediction = pd.DataFrame(test_pred)
prediction.head(20)
# Out:
#       0         1         2         3         4         5         6      \
# 0  0.307238  0.426465  0.317565  0.724540  0.179597  0.351441  0.354154
# 1  0.350573  0.421721  0.343228  0.766215  0.192347  0.361689  0.354989
# 2  0.332358  0.400112  0.365133  0.739791  0.164978  0.338426  0.371815
# 3  0.329002  0.489214  0.368067  0.743832  0.191976  0.377625  0.387725
# 4  0.327381  0.398524  0.370006  0.741985  0.185719  0.357780  0.365768
# 5  0.334653  0.381019  0.373213  0.765750  0.161909  0.380601  0.377921
# 6  0.297789  0.396647  0.332791  0.736783  0.198272  0.341091  0.344166
# 7  0.353159  0.376381  0.324921  0.748355  0.182834  0.340111  0.383071
#
#       7         8         9         10        11        12        13     \
# 0  0.571887  0.441624  0.311105  0.106142  0.020863  0.495415  0.037564
# 1  0.581771  0.429117  0.291991  0.110035  0.021566  0.574883  0.036946
# 2  0.594996  0.445185  0.336160  0.096541  0.020655  0.587299  0.037831
# 3  0.565373  0.376052  0.321451  0.109696  0.020821  0.616725  0.039374
# 4  0.566745  0.427907  0.316415  0.103384  0.021591  0.553572  0.042872
# 5  0.588542  0.407711  0.308087  0.096910  0.021103  0.594328  0.039919
# 6  0.572635  0.396090  0.318221  0.104108  0.022023  0.561932  0.039593
# 7  0.589725  0.392793  0.354572  0.107610  0.019824  0.546489  0.040560
#
#       14        15        16        17        18        19        20     \
# 0  0.472006  0.615795  0.328580  0.062375  0.123187  0.752210  0.063780
# 1  0.467886  0.667075  0.320586  0.059425  0.131841  0.712208  0.074158
# 2  0.479122  0.697518  0.308992  0.060217  0.116355  0.713701  0.069268
# 3  0.502586  0.605018  0.306697  0.058069  0.123489  0.744905  0.071342
# 4  0.509597  0.632379  0.317578  0.059384  0.126309  0.738496  0.077708
# 5  0.527056  0.623258  0.337042  0.054130  0.127598  0.734794  0.066995
# 6  0.496878  0.669883  0.319566  0.058754  0.120514  0.725633  0.076682
# 7  0.481033  0.634493  0.317256  0.062069  0.127707  0.716865  0.073927
#
#       21        22        23        24        25        26        27     \
# 0  0.083749  0.052856  0.265303  0.022889  0.039999  0.473683  0.041316
# 1  0.091020  0.056897  0.263824  0.027237  0.035782  0.477242  0.041973
# 2  0.097246  0.050871  0.271934  0.027707  0.038601  0.434139  0.041103
# 3  0.086287  0.054026  0.275549  0.024920  0.035210  0.457732  0.039276
# 4  0.088737  0.050395  0.259352  0.022893  0.036830  0.462557  0.038754
# 5  0.088166  0.054602  0.234172  0.025683  0.035151  0.433320  0.038528
# 6  0.084421  0.052233  0.272037  0.030003  0.039969  0.441134  0.043861
# 7  0.087207  0.054242  0.278959  0.025087  0.035609  0.485509  0.039291
#
#       28        29        30        31        32        33        34     \
# 0  0.136233  0.079851  0.630841  0.321070  0.090578  0.184503  0.325640
# 1  0.137254  0.079000  0.615606  0.302090  0.089296  0.199556  0.309012
# 2  0.139389  0.075946  0.625800  0.292103  0.082212  0.204037  0.320293
# 3  0.139336  0.074546  0.606280  0.310985  0.075763  0.201782  0.326979
# 4  0.140692  0.070269  0.619378  0.308346  0.082967  0.203413  0.314842
# 5  0.134984  0.077018  0.631732  0.321839  0.074654  0.212188  0.306178
# 6  0.129712  0.073127  0.629974  0.309476  0.068705  0.198489  0.299800
# 7  0.136965  0.081177  0.608423  0.341491  0.073833  0.206637  0.306062
#
#       35        36        37        38        39     ...     23960     23961  \
# 0  0.695526  0.083338  0.107724  0.019648  0.006139  ...  0.016094  0.110182
# 1  0.686714  0.103317  0.111242  0.017328  0.004751  ...  0.016966  0.122372
# 2  0.696698  0.094414  0.109789  0.016712  0.005637  ...  0.015958  0.113820
# 3  0.692986  0.091261  0.098756  0.016723  0.005437  ...  0.016408  0.110810
# 4  0.689257  0.088993  0.107738  0.020125  0.005215  ...  0.017744  0.110347
# 5  0.689921  0.101398  0.102132  0.016694  0.005001  ...  0.016555  0.120298
# 6  0.672189  0.107117  0.103175  0.020109  0.005759  ...  0.015833  0.118410
# 7  0.667444  0.098224  0.099977  0.018903  0.005801  ...  0.014044  0.107005
#
#       23962     23963     23964     23965     23966     23967     23968  \
# 0  0.119363  0.006385  0.006696  0.306314  0.137413  0.089931  0.017228
# 1  0.110393  0.006669  0.006074  0.292242  0.133856  0.094261  0.019515
# 2  0.103083  0.005972  0.006042  0.289584  0.140018  0.097606  0.019401
# 3  0.103494  0.006269  0.006336  0.311137  0.124835  0.105232  0.017843
# 4  0.113495  0.006206  0.006144  0.290843  0.135147  0.090608  0.018345
# 5  0.105768  0.006059  0.006199  0.308592  0.134883  0.095648  0.018877
# 6  0.113024  0.006916  0.006790  0.284410  0.122876  0.091720  0.018927
# 7  0.096229  0.006449  0.006925  0.281461  0.134670  0.095826  0.020188
#
#       23969     23970     23971     23972     23973     23974     23975  \
# 0  0.083928  0.418752  0.324399  0.128662  0.016954  0.123627  0.193205
# 1  0.090406  0.459302  0.310814  0.135707  0.015951  0.136624  0.173629
# 2  0.090510  0.432122  0.316588  0.127852  0.015772  0.142256  0.159529
# 3  0.090750  0.431247  0.308195  0.122879  0.015036  0.134019  0.152683
# 4  0.090441  0.417177  0.309050  0.120128  0.015283  0.141809  0.167170
# 5  0.096677  0.431600  0.322585  0.130942  0.016409  0.131448  0.152329
# 6  0.089684  0.416452  0.315033  0.135162  0.015681  0.112626  0.155970
# 7  0.086513  0.425830  0.312377  0.124532  0.017665  0.133717  0.152494
#
#       23976     23977     23978     23979     23980     23981     23982  \
# 0  0.009869  0.071036  0.015142  0.378369  0.054117  0.481032  0.405166
# 1  0.010588  0.062472  0.014698  0.372173  0.055687  0.508415  0.409368
# 2  0.010836  0.069742  0.015056  0.384331  0.059439  0.512325  0.391859
# 3  0.010337  0.066661  0.016742  0.404963  0.055102  0.493996  0.405202
# 4  0.011828  0.074293  0.015557  0.399716  0.056172  0.472293  0.341806
# 5  0.010442  0.071278  0.014632  0.391806  0.048268  0.514877  0.378043
# 6  0.010656  0.065045  0.016229  0.399427  0.052963  0.461697  0.336196
# 7  0.010374  0.067889  0.014942  0.383255  0.048805  0.501560  0.390880
#
#       23983     23984     23985     23986     23987     23988     23989  \
# 0  0.581478  0.508879  0.288625  0.524648  0.288082  0.413376  0.039607
# 1  0.525492  0.524706  0.274319  0.540118  0.323627  0.481267  0.039726
# 2  0.553798  0.562730  0.314378  0.504974  0.345084  0.438778  0.038427
# 3  0.581391  0.515982  0.301417  0.499189  0.317434  0.452972  0.040205
# 4  0.515411  0.510656  0.322251  0.449049  0.271284  0.552417  0.037048
# 5  0.530500  0.538132  0.322147  0.506171  0.308566  0.446920  0.037075
# 6  0.525846  0.494466  0.303252  0.481918  0.320759  0.444013  0.039174
# 7  0.536893  0.514093  0.273935  0.484241  0.289751  0.453533  0.038415
#
#       23990     23991     23992     23993     23994     23995     23996  \
# 0  0.413774  0.605498  0.856668  0.657674  0.140642  0.713136  0.245325
# 1  0.462373  0.606562  0.839268  0.598163  0.132151  0.700705  0.264211
# 2  0.465141  0.618054  0.853749  0.586486  0.124530  0.728394  0.235578
# 3  0.443587  0.602757  0.862975  0.633762  0.123985  0.695169  0.296794
# 4  0.438867  0.605884  0.855925  0.640356  0.126873  0.692529  0.243663
# 5  0.429015  0.630545  0.857516  0.628713  0.128392  0.700835  0.255230
# 6  0.440361  0.612365  0.835029  0.593665  0.130898  0.679709  0.222073
# 7  0.455629  0.634637  0.825289  0.631249  0.124317  0.705447  0.267779
#
#       23997     23998     23999
# 0  0.295344  0.529405  0.173798
# 1  0.263486  0.550849  0.185775
# 2  0.282176  0.518191  0.188491
# 3  0.294250  0.554305  0.205337
# 4  0.315421  0.485735  0.180472
# 5  0.286580  0.560082  0.195576
# 6  0.277608  0.518973  0.200958
# 7  0.276246  0.532381  0.170886
#
# [8 rows x 24000 columns]

# %%
dt = pd.read_csv('Test.csv')
output = pd.DataFrame({'Applicant_ID' : dt['Applicant_ID'], "default_status": np.mean(prediction, axis = 0)})

# %%
output.head(50)
# Out:
#      Applicant_ID  default_status
# 0   Apcnt_1000032        0.329019
# 1   Apcnt_1000048        0.411260
# 2   Apcnt_1000052        0.349365
# 3   Apcnt_1000076        0.745906
# 4   Apcnt_1000080        0.182204
# 5   Apcnt_1000084        0.356096
# 6   Apcnt_1000104        0.367451
# 7   Apcnt_1000116        0.578959
# 8   Apcnt_1000128        0.414560
# 9   Apcnt_1000156        0.319750
# 10  Apcnt_1000192        0.104303
# 11  Apcnt_1000208        0.021056
# 12  Apcnt_1000264        0.566330
# 13  Apcnt_1000288        0.039332
# 14  Apcnt_1000292        0.492021
# 15  Apcnt_1000328        0.643177
# 16  Apcnt_1000336        0.319537
# 17  Apcnt_1000356        0.059303
# 18  Apcnt_1000368        0.124625
# 19  Apcnt_1000372        0.729852
# 20  Apcnt_1000392        0.071733
# 21  Apcnt_1000396        0.088354
# 22  Apcnt_1000400        0.053265
# 23  Apcnt_1000416        0.265141
# 24  Apcnt_1000428        0.025802
# 25  Apcnt_1000440        0.037144
# 26  Apcnt_1000456        0.458165
# 27  Apcnt_1000472        0.040513
# 28  Apcnt_1000488        0.136821
# 29  Apcnt_1000492        0.076367
# 30  Apcnt_1000504        0.621005
# 31  Apcnt_1000516        0.313425
# 32  Apcnt_1000532        0.079751
# 33  Apcnt_1000552        0.201326
# 34  Apcnt_1000564        0.313601
# 35  Apcnt_1000576        0.686342
# 36  Apcnt_1000596        0.096008
# 37  Apcnt_1000620        0.105067
# 38  Apcnt_1000624        0.018280
# 39  Apcnt_1000636        0.005467
# 40  Apcnt_1000648        0.032223
# 41  Apcnt_1000668        0.039635
# 42  Apcnt_1000680        0.117140
# 43  Apcnt_1000696        0.044053
# 44  Apcnt_1000704        0.489579
# 45  Apcnt_1000724        0.044610
# 46  Apcnt_1000740        0.267047
# 47  Apcnt_1000744        0.014783
# 48  Apcnt_1000756        0.033797
# 49  Apcnt_1000768        0.005680

# %%
output.to_csv('Finally3.csv', index= False)

# %%
## Averaging/Weighted Averaging of best submissions

# %%
dat1 = pd.read_csv('S1.csv')
dat2 = pd.read_csv('S2.csv')
dat3 = pd.read_csv('S4.csv')
dat4 = pd.read_csv('S3.csv')


dat5 = pd.read_csv('10C_MODELcrossVal.csv')
dat6 = pd.read_csv('Final5.csv')

dat6 = pd.read_csv('Finalllo.csv')
dat7 = pd.read_csv('Finalllimm.csv')
dat8 = pd.read_csv('Finalllii.csv')
dat9 = pd.read_csv('FL.csv')
dat10 = pd.read_csv('FL2.csv')

# %%
datt = (dat2['default_status'] + dat6['default_status']+dat7['default_status'] + dat8['default_status']+dat9['default_status']+dat10['default_status'])/6
#datt = (dat1['default_status'] + dat2['default_status'] + dat3['default_status'])/3
#datt = 0.4*(dat2['default_status']) + 0.3*(dat3['default_status']) + 0.3*(dat1['default_status'])

# %%
df = pd.read_csv('SampleSubmission.csv')
df['default_status'] = datt
df.to_csv('FL3.csv', index = False)

# %%
df.head()
# Out:
#     Applicant_ID  default_status
# 0  Apcnt_1000032        0.314835
# 1  Apcnt_1000048        0.392888
# 2  Apcnt_1000052        0.375079
# 3  Apcnt_1000076        0.744925
# 4  Apcnt_1000080        0.157771
